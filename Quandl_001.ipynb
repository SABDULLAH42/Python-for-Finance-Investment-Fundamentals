# %%
pip install quandl
# Out:
# ...
#      -------------------------------------- 55.8/55.8 kB 723.6 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import quandl

# %% [markdown]
# # API key

# %%
quandl.ApiConfig.api_key = "U9-QyjWPD_w8UPd2Duyq"

# %% [markdown]
# # Important Command

# %%
mydata = quandl.get("EIA/PET_RWTC_D")

# %%
mydata
# Out:
#             Value
# Date
# 1986-01-02  25.56
# 1986-01-03  26.00
# 1986-01-06  26.53
# 1986-01-07  25.85
# 1986-01-08  25.87
# ...           ...
# 2022-02-02  88.16
# 2022-02-03  90.17
# 2022-02-04  92.27
# 2022-02-07  91.25
# 2022-02-08  89.32
#
# [9124 rows x 1 columns]

# %%
mydata = quandl.get("FRED/GDP", start_date="2019-12-31", end_date="2020-9-26")

# %%
mydata
# Out:
#                 Value
# Date
# 2020-01-01  21481.367
# 2020-04-01  19477.444
# 2020-07-01  21138.574

# %%
import pandas as pd

# %%
df= pd.DataFrame(mydata, columns = ['Date', 'Value'])

# %%
df.to_csv('US_GDP.csv')

# %%
aapl = quandl.get("WIKI/AAPL", start_date="2014-1-1" , end_date="2016-1-1")

# %%
aapl.describe()
# Out:
#              Open        High         Low       Close        Volume  \
# count  504.000000  504.000000  504.000000  504.000000  5.040000e+02
# mean   207.655886  209.401200  205.933348  207.720361  4.325065e+07
# std    181.295916  182.711415  180.209083  181.596856  2.529600e+07
# min     90.210000   90.700000   89.650000   90.280000  5.704900e+06
# 25%    108.965000  109.877500  107.357500  108.807500  2.884406e+07
# 50%    118.185000  119.275000  116.990000  118.627500  4.299648e+07
# 75%    130.005000  130.872500  128.962500  129.985000  5.569448e+07
# max    649.900000  651.260000  644.470000  647.350000  1.895606e+08
#
#        Ex-Dividend  Split Ratio   Adj. Open   Adj. High    Adj. Low  \
# count   504.000000   504.000000  504.000000  504.000000  504.000000
# mean      0.018472     1.011905  101.022717  101.910366  100.050240
# std       0.206401     0.267261   17.647335   17.778989   17.408633
# min       0.000000     1.000000   65.820564   66.664622   65.603901
# ...
