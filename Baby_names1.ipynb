# %%
import math
import collections

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
from zipfile import ZipFile
import os
babyNames=ZipFile('C:\\Users\\USER\\Desktop\\LINKEDIN_LEARNING\\names.zip')
os.chdir('C:\\Users\\USER\Desktop\\TCS APPLICATION\\Marksheet')
babyNames.extractall()

# %%
pd.options.display.max_rows=8

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is EC65-8CF9
#
#  Directory of C:\Users\USER\Desktop\TCS APPLICATION\Marksheet
#
# 12-08-2023  02:04    <DIR>          .
# 12-08-2023  02:04    <DIR>          ..
# 12-08-2023  01:09            14,421 1st SEM MARKSHEET.pdf
# 12-08-2023  01:09            14,478 2nd SEM MARKSHEET.pdf
# 12-08-2023  01:09            12,199 3rd SEM MARKSHEET.pdf
# 12-08-2023  01:09            26,621 4th SEM MARKSHEET.pdf
# 12-08-2023  02:37            24,933 yob1880.txt
# 12-08-2023  02:37            24,052 yob1881.txt
# 12-08-2023  02:37            26,559 yob1882.txt
# 12-08-2023  02:37            26,002 yob1883.txt
# 12-08-2023  02:37            28,670 yob1884.txt
# 12-08-2023  02:37            28,625 yob1885.txt
# 12-08-2023  02:37            29,822 yob1886.txt
# 12-08-2023  02:37            29,531 yob1887.txt
# 12-08-2023  02:37            33,064 yob1888.txt
# 12-08-2023  02:37            32,297 yob1889.txt
# ...

# %%
open('C:\\Users\\USER\\Desktop\\TCS APPLICATION\Marksheet\\yob2011.txt','r').readlines()[:10]
# Out:
# ['Sophia,F,21856\n',
#  'Isabella,F,19927\n',
#  'Emma,F,18814\n',
#  'Olivia,F,17331\n',
#  'Ava,F,15512\n',
#  'Emily,F,14270\n',
#  'Abigail,F,13257\n',
#  'Madison,F,12399\n',
#  'Mia,F,11533\n',
#  'Chloe,F,11002\n']

# %%
pd.read_csv('C:\\Users\\USER\\Desktop\\TCS APPLICATION\Marksheet\\yob2011.txt')
# Out:
#          Sophia  F  21856
# 0      Isabella  F  19927
# 1          Emma  F  18814
# 2        Olivia  F  17331
# 3           Ava  F  15512
# ...         ... ..    ...
# 33929     Zylas  M      5
# 33930     Zyran  M      5
# 33931   Zyshawn  M      5
# 33932  Zytavion  M      5
#
# [33933 rows x 3 columns]

# %%
pd.read_csv('C:\\Users\\USER\\Desktop\\TCS APPLICATION\Marksheet\\yob2011.txt', names=['name','sex','number'])
# Out:
#            name sex  number
# 0        Sophia   F   21856
# 1      Isabella   F   19927
# 2          Emma   F   18814
# 3        Olivia   F   17331
# ...         ...  ..     ...
# 33930     Zylas   M       5
# 33931     Zyran   M       5
# 33932   Zyshawn   M       5
# 33933  Zytavion   M       5
#
# [33934 rows x 3 columns]

# %%
#using dataframe assign
pd.read_csv('C:\\Users\\USER\\Desktop\\TCS APPLICATION\Marksheet\\yob2011.txt', names=['name','sex','number']).assign(year=2011)
# Out:
#            name sex  number  year
# 0        Sophia   F   21856  2011
# 1      Isabella   F   19927  2011
# 2          Emma   F   18814  2011
# 3        Olivia   F   17331  2011
# ...         ...  ..     ...   ...
# 33930     Zylas   M       5  2011
# 33931     Zyran   M       5  2011
# 33932   Zyshawn   M       5  2011
# 33933  Zytavion   M       5  2011
#
# [33934 rows x 4 columns]

# %%
allyears =pd.concat(pd.read_csv(f'C:\\Users\\USER\\Desktop\\TCS APPLICATION\\Marksheet\\yob2011.txt', names=['name','sex','number'])
                   .assign(year=year) for year in range(1880,2019))

# %%
allyears.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4716826 entries, 0 to 33933
# Data columns (total 4 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   name    object
#  1   sex     object
#  2   number  int64
#  3   year    int64
# dtypes: int64(2), object(2)
# memory usage: 179.9+ MB

# %%
allyears.year.min(), allyears.year.max()
# Out:
# (1880, 2018)

# %%
pd.read_csv('C:\\Users\\USER\\Desktop\\TCS APPLICATION\Marksheet\\yob2011.txt', names=['name','sex','number']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33934 entries, 0 to 33933
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    33934 non-null  object
#  1   sex     33934 non-null  object
#  2   number  33934 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 795.5+ KB

# %%
#Saving the merged datafram using to_CSV
allyears.to_csv('allyears.csv.gz', index=False)
