# %%
import numpy as np
from pandas_datareader import data as pdr
import matplotlib.pyplot as plt
import yfinance as yfin

# %%
yfin.pdr_override()

# %%
PG = yfin.download('PG', start='1995-1-1')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
PG.head()
# Out:
#                 Open      High       Low     Close  Adj Close   Volume
# Date
# 1995-01-03  15.46875  15.62500  15.43750  15.59375   7.626413  3318400
# 1995-01-04  15.53125  15.65625  15.31250  15.46875   7.565284  2218800
# 1995-01-05  15.37500  15.43750  15.21875  15.25000   7.458302  2319600
# 1995-01-06  15.15625  15.40625  15.15625  15.28125   7.473586  3438000
# 1995-01-09  15.34375  15.40625  15.18750  15.21875   7.443014  1795200

# %%
PG['log_return'] = np.log(PG['Adj Close'] / PG['Adj Close'].shift(1))
print(PG['log_return'])
# Out:
# Date
# 1995-01-03         NaN
# 1995-01-04   -0.008048
# 1995-01-05   -0.014242
# 1995-01-06    0.002047
# 1995-01-09   -0.004099
#                 ...
# 2023-11-27   -0.000925
# 2023-11-28    0.006919
# 2023-11-29   -0.007646
# 2023-11-30    0.015690
# 2023-12-01   -0.005618
# Name: log_return, Length: 7281, dtype: float64

# %%
PG['log_return'].plot(figsize=(8,5))
plt.show()

# %%
log_return_d = PG['log_return'].mean()
log_return_d
# Out:
# 0.00041162027311489866

# %%
log_return_a = PG['log_return'].mean() * 250
log_return_a
# Out:
# 0.10290506827872467

# %%
print (str(round(log_return_a, 5) * 100) + ' %')
# Out:
# 10.291 %
